# %%
import os
from os import path

# %%
data_path = "/data"

# %% [markdown]
# # Image Segmentation

# %% [markdown]
# We use the The Berkeley Segmentation Dataset and Benchmark, available from https://www2.eecs.berkeley.edu/Research/Projects/CS/vision/bsds/.

# %%
seg_data_path = path.join(data_path, "bsds")

# %%
images = "https://www2.eecs.berkeley.edu/Research/Projects/CS/vision/bsds/BSDS300-images.tgz"
segmentations = "https://www2.eecs.berkeley.edu/Research/Projects/CS/vision/bsds/BSDS300-human.tgz"

# %%
# %%bash -s "$seg_data_path" "$images" "$segmentations"
# wget $2 -P $1
# wget $3 -P $1
# Out:
# --2018-01-28 08:54:57--  https://www2.eecs.berkeley.edu/Research/Projects/CS/vision/bsds/BSDS300-images.tgz
# Resolving www2.eecs.berkeley.edu (www2.eecs.berkeley.edu)... 128.32.244.183
# Connecting to www2.eecs.berkeley.edu (www2.eecs.berkeley.edu)|128.32.244.183|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22211847 (21M) [application/x-tar]
# Saving to: '/data/bsds/BSDS300-images.tgz.1'
#
#      0K .......... .......... .......... .......... ..........  0% 23.4K 15m24s
#     50K .......... .......... .......... .......... ..........  0%  238K 8m26s
#    100K .......... .......... .......... .......... ..........  0%  230K 6m8s
#    150K .......... .......... .......... .......... ..........  0% 50.0M 4m35s
#    200K .......... .......... .......... .......... ..........  1% 6.35K 14m55s
#    250K .......... .......... .......... .......... ..........  1% 3.93K 27m31s
#    300K .......... .......... .......... .......... ..........  1% 79.4K 24m10s
# ...

# %%
# Out:
# wget: missing URL
# Usage: wget [OPTION]... [URL]...
#
# Try `wget --help' for more options.

# %%
w
